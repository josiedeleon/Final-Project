# %% [markdown]
# # White Wine Classification

# %%
import pandas as pd
#import numpy as np
#import math 
#import matplotlib.pyplot as plt

# %% [markdown]
# # Ready CSV

# %%
df = pd.read_csv("./Resources/Data/winequality-white-clean.csv", delimiter=',')
#df = pd.read_csv("./Resources/Data/winequality-white-clean-correlation.csv", delimiter=',')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 3952            6.2              0.21         0.29             1.6      0.039
# 3953            6.6              0.32         0.36             8.0      0.047
# 3954            6.5              0.24         0.19             1.2      0.041
# 3955            5.5              0.29         0.30             1.1      0.022
# 3956            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 3952                 24.0                  92.0  0.99114  3.27       0.50
# 3953                 57.0                 168.0  0.99490  3.15       0.46
# 3954                 30.0                 111.0  0.99254  2.99       0.46
# 3955                 20.0                 110.0  0.98869  3.34       0.38
# 3956                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol    quality
# 0         8.8       Fair
# 1         9.5       Fair
# 2        10.1       Fair
# 3         9.9       Fair
# 4         9.6       Fair
# ...       ...        ...
# 3952     11.2       Fair
# 3953      9.6       Fair
# 3954      9.4       Fair
# 3955     12.8  Very Good
# 3956     11.8       Fair
#
# [3957 rows x 12 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(['quality'], axis = 1)
X.shape
# Out:
# (3957, 11)

# %%
y = df['quality']
y.shape
# Out:
# (3957,)

# %%
#from sklearn.ensemble import ExtraTreesClassifier
#white_dl_model = ExtraTreesClassifier()
#white_dl_model.fit(X, y)
#print(white_dl_model.feature_importances_)
#feat_importances = pd.Series(white_dl_model.feature_importances_, index=X_names)
#feat_importances.nlargest(10).plot(kind= "barh" , color = "#EEEDC4")
#plt.show()

# %% [markdown]
# # Create a Train Test Split

# %%
# Split the data using train_test_split

from sklearn.model_selection import train_test_split

X_train, X_, y_train, y_ = train_test_split(X,y,train_size=.7,random_state=3)
X_val,X_test, y_val, y_test = train_test_split(X_,y_,train_size=.7,random_state=3)

X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((2769, 11), (831, 11), (357, 11), (2769,), (831,), (357,))

# %%
#Train your first model with default parameters
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(oob_score=True)
rf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf = rf.fit(X_train, y_train)
#what is the percentage of accuracy
rf.score(X_train, y_train)
#the score shows the percentage that are correct
# Out:
# 1.0

# %%
rf.oob_score_
# Out:
# 0.8237630913687252

# %%
##what is the percentage of accuracy for the validaton set
rf.score(X_val, y_val)
# Out:
# 0.838748495788207

# %%
# One more dwiting with parameters
rf2 = RandomForestClassifier(oob_score=True,max_depth=3)
rf2
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=3, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf2 = rf.fit(X_train, y_train)
rf2.score(X_train, y_train)
# Out:
# 1.0

# %%
rf2.oob_score_
# Out:
# 0.8223185265438786

# %%
rf2.score(X_val, y_val)
# Out:
# 0.8531889290012034

# %%
#Not good because the train went up and the validation went down. it is overfitting

# %%
rf3 = RandomForestClassifier(max_depth=5,oob_score=True)
rf3
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf3 = rf.fit(X_train, y_train)
rf3.score(X_train, y_train)
# Out:
# 1.0

# %%
rf3.oob_score_
# Out:
# 0.8194293968941856

# %%
rf3.score(X_val, y_val)
# Out:
# 0.8459687123947052

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf.feature_importances_
importances
#it tells you that the 4th feature is the most important
# Out:
# array([0.06784689, 0.07660898, 0.06625369, 0.08846647, 0.08660468,
#        0.08582515, 0.08742327, 0.12994937, 0.07977545, 0.07278998,
#        0.15845608])

# %%
# We can sort the features by their importance
sorted(zip(rf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.1584560753606487, 'alcohol'),
#  (0.12994937159067935, 'density'),
#  (0.08846646544873933, 'residual sugar'),
#  (0.08742327066539886, 'total sulfur dioxide'),
#  (0.08660468336093498, 'chlorides'),
#  (0.08582514871239069, 'free sulfur dioxide'),
#  (0.0797754476479785, 'pH'),
#  (0.07660898118353714, 'volatile acidity'),
#  (0.07278997693863826, 'sulphates'),
#  (0.06784689358677914, 'fixed acidity'),
#  (0.06625368550427496, 'citric acid')]

# %%
X.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model



# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV

# param_grid = {'n_estimators':[100, 200], 
#                 'random_state':[0,1,2,3],
#                 'max_depth': [1,2,3,4]  }
# param_grid = {'n_estimators':[100, 200, 300], 
#                'random_state':[0,1,2,3],
#                'max_depth': [1,2,3,4]  }
#Final 0.8179 -9.5 minutes
param_grid = {'n_estimators':[100, 200, 300], 
              'random_state':[0,1,2,3,4,5],
              'max_depth': [1,2,3,4,5],
              'max_features': ['sqrt', 'log2', None]}
#14 minutes  Final 0.80  
# param_grid = {'max_depth':[1,2,3,4,5], 
#                'min_samples_leaf':[1,2,3,4,5],
# #              'max_samples_leaf':[2,3,4,5],
#               'criterion':['gini','entropy'],
#               'n_estimators':[100, 200, 300], 
#               'random_state':[0,1,2,3]}
              
grid = GridSearchCV(rf, param_grid, verbose=3, return_train_score=True)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=0, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=1, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=2, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=3, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=4, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=100, random_state=5, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=0, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=1, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=2, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=3, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=4, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=200, random_state=5, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=0, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=1, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=2, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=2, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=2, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=2, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=2, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=3, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=3, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=3, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=3, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=3, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=4, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=4, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=4, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=4, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=4, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=5, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=5, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=5, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=5, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=sqrt, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=sqrt, n_estimators=300, random_state=5, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=0, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=1, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=2, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=3, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=4, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=100, random_state=5, score=(train=0.788, test=0.788), total=   0.1s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=0, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=1, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=2, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=3, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=4, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=200, random_state=5, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=0, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=1, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=2, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=2, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=2, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=2, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=2, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=3, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=3, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=3, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=3, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=3
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=3, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=4, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=4, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=4, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=4, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=4
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=4, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=5, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=5, score=(train=0.788, test=0.789), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=5, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=5, score=(train=0.788, test=0.787), total=   0.4s
# [CV] max_depth=1, max_features=log2, n_estimators=300, random_state=5
# [CV]  max_depth=1, max_features=log2, n_estimators=300, random_state=5, score=(train=0.788, test=0.788), total=   0.4s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=0, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=0, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=0, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=1, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=1, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=1, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=2, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=2, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=2, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=3, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=3, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=3, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=4, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=4, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=4, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=5, score=(train=0.788, test=0.789), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=5, score=(train=0.788, test=0.787), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=100, random_state=5, score=(train=0.788, test=0.788), total=   0.2s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=0, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=0, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=0, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=1, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=1, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=1, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=2, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=2, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=2, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=3, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=3, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=3, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=4, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=4, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=4, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=5, score=(train=0.788, test=0.789), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=5, score=(train=0.788, test=0.787), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=1, max_features=None, n_estimators=200, random_state=5, score=(train=0.788, test=0.788), total=   0.3s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=0, score=(train=0.788, test=0.789), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=0, score=(train=0.788, test=0.787), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=0, score=(train=0.788, test=0.788), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=1, score=(train=0.788, test=0.789), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=1, score=(train=0.788, test=0.787), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=1, score=(train=0.788, test=0.788), total=   0.5s
# [CV] max_depth=1, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=1, max_features=None, n_estimators=300, random_state=2, score=(train=0.788, test=0.789), total=   0.5s
# ...
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=2, score=(train=0.853, test=0.832), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=3, score=(train=0.854, test=0.816), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=3, score=(train=0.855, test=0.800), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=3, score=(train=0.846, test=0.801), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=3, score=(train=0.857, test=0.809), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=3, score=(train=0.850, test=0.828), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=4, score=(train=0.850, test=0.812), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=4, score=(train=0.853, test=0.798), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=4, score=(train=0.848, test=0.801), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=4, score=(train=0.857, test=0.805), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=4, score=(train=0.848, test=0.832), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=5, score=(train=0.855, test=0.812), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=5, score=(train=0.858, test=0.800), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=5, score=(train=0.845, test=0.801), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=5, score=(train=0.854, test=0.807), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=100, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=100, random_state=5, score=(train=0.852, test=0.835), total=   0.4s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=0, score=(train=0.856, test=0.809), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=0, score=(train=0.856, test=0.792), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=0, score=(train=0.847, test=0.807), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=0, score=(train=0.857, test=0.812), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=0, score=(train=0.848, test=0.837), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=1, score=(train=0.852, test=0.810), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=1, score=(train=0.856, test=0.794), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=1, score=(train=0.846, test=0.807), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=1, score=(train=0.858, test=0.803), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=1, score=(train=0.853, test=0.835), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=2, score=(train=0.854, test=0.809), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=2, score=(train=0.856, test=0.798), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=2, score=(train=0.843, test=0.812), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=2, score=(train=0.858, test=0.805), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=2, score=(train=0.847, test=0.834), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=3, score=(train=0.854, test=0.814), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=3, score=(train=0.858, test=0.807), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=3, score=(train=0.846, test=0.805), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=3, score=(train=0.857, test=0.810), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=3, score=(train=0.847, test=0.835), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=4, score=(train=0.853, test=0.809), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=4, score=(train=0.857, test=0.800), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=4, score=(train=0.847, test=0.805), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=4, score=(train=0.856, test=0.805), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=4, score=(train=0.846, test=0.834), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=5, score=(train=0.856, test=0.812), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=5, score=(train=0.858, test=0.796), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=5, score=(train=0.847, test=0.801), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=5, score=(train=0.856, test=0.807), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=200, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=200, random_state=5, score=(train=0.853, test=0.839), total=   0.8s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=0, score=(train=0.858, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=0, score=(train=0.856, test=0.796), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=0, score=(train=0.849, test=0.807), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=0, score=(train=0.857, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=0
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=0, score=(train=0.847, test=0.834), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=1, score=(train=0.852, test=0.810), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=1, score=(train=0.856, test=0.798), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=1, score=(train=0.846, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=1, score=(train=0.860, test=0.805), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=1
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=1, score=(train=0.852, test=0.832), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=2, score=(train=0.855, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=2, score=(train=0.859, test=0.800), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=2, score=(train=0.847, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=2, score=(train=0.856, test=0.803), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=2
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=2, score=(train=0.847, test=0.837), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=3, score=(train=0.858, test=0.812), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=3, score=(train=0.857, test=0.803), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=3, score=(train=0.847, test=0.805), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=3, score=(train=0.856, test=0.805), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=3
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=3, score=(train=0.846, test=0.835), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=4, score=(train=0.852, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=4, score=(train=0.859, test=0.803), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=4, score=(train=0.848, test=0.807), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=4, score=(train=0.857, test=0.805), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=4
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=4, score=(train=0.849, test=0.835), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=5, score=(train=0.854, test=0.814), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=5, score=(train=0.859, test=0.800), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=5, score=(train=0.848, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=5, score=(train=0.859, test=0.809), total=   1.2s
# [CV] max_depth=5, max_features=None, n_estimators=300, random_state=5
# [CV]  max_depth=5, max_features=None, n_estimators=300, random_state=5, score=(train=0.851, test=0.837), total=   1.2s
# [Parallel(n_jobs=1)]: Done 1350 out of 1350 | elapsed:  9.5min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=True, random_state=None,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 200, 300],
#                          'random_state': [0, 1, 2, 3, 4, 5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'random_state': 4}
# 0.8158237640438436

# %%
#Now that  found my best parameters I combine train and val and I do it one more time

# %%
best_rf = grid.best_estimator_
best_rf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=True, random_state=4, verbose=0,
#                        warm_start=False)

# %%
best_rf.fit(X_train, y_train)
print(best_rf.score(X_train, y_train), best_rf.score(X_val, y_val))
# Out:
# 0.8429035752979415 0.8351383874849578

# %%
X_train = pd.concat([X_train, X_val], ignore_index=True)
y_train = pd.concat([y_train, y_val], ignore_index=True)
best_rf.fit(X_train, y_train)
print(best_rf.score(X_train,y_train), best_rf.score(X_val,y_val))
# Out:
# 0.84 0.8531889290012034

# %%
print(f'Final result {best_rf.score(X_test,y_test)}')
# Out:
# Final result 0.8179271708683473

# %%
predictions = best_rf.predict(X_test)
#predictions

# %%
actual = y_test.tolist()
#actual

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction     Actual
# 0         Fair       Fair
# 1         Fair       Fair
# 2         Fair       Fair
# 3         Fair  Very Good
# 4         Fair       Fair
# ..         ...        ...
# 352       Fair  Very Good
# 353       Fair       Fair
# 354       Fair       Fair
# 355       Fair       Fair
# 356       Fair       Fair
#
# [357 rows x 2 columns]

# %%
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Fair' 'Fair' 'Fair' 'Fair' 'Fair' 'Fair' 'Fair' 'Fair' 'Fair' 'Fair']
# First 10 Actual labels: ['Fair', 'Fair', 'Fair', 'Very Good', 'Fair', 'Fair', 'Fair', 'Fair', 'Fair', 'Fair']

# %%
# Calculate classification report
y_names = ['Fair','Very Good']
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=y_names))
# Out:
#               precision    recall  f1-score   support
#
#         Fair       0.83      0.96      0.89       285
#    Very Good       0.63      0.24      0.34        72
#
#     accuracy                           0.82       357
#    macro avg       0.73      0.60      0.62       357
# weighted avg       0.79      0.82      0.78       357

# %%
results = pd.DataFrame(grid.cv_results_)
results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.123987      0.012733         0.006308        0.000092
# 1         0.117807      0.002710         0.006411        0.000147
# 2         0.116162      0.000442         0.006338        0.000120
# 3         0.118458      0.001084         0.006520        0.000189
# 4         0.118392      0.001769         0.006466        0.000212
# ..             ...           ...              ...             ...
# 265       1.144765      0.001264         0.020877        0.000114
# 266       1.145528      0.003666         0.020875        0.000022
# 267       1.151302      0.008218         0.021025        0.000059
# 268       1.150626      0.005227         0.020929        0.000211
# 269       1.149096      0.007014         0.020919        0.000195
#
#     param_max_depth param_max_features param_n_estimators param_random_state  \
# 0                 1               sqrt                100                  0
# 1                 1               sqrt                100                  1
# 2                 1               sqrt                100                  2
# 3                 1               sqrt                100                  3
# 4                 1               sqrt                100                  4
# ..              ...                ...                ...                ...
# 265               5               None                300                  1
# 266               5               None                300                  2
# 267               5               None                300                  3
# 268               5               None                300                  4
# 269               5               None                300                  5
#
#                                                 params  split0_test_score  \
# 0    {'max_depth': 1, 'max_features': 'sqrt', 'n_es...           0.788809
# 1    {'max_depth': 1, 'max_features': 'sqrt', 'n_es...           0.788809
# 2    {'max_depth': 1, 'max_features': 'sqrt', 'n_es...           0.788809
# 3    {'max_depth': 1, 'max_features': 'sqrt', 'n_es...           0.788809
# 4    {'max_depth': 1, 'max_features': 'sqrt', 'n_es...           0.788809
# ..                                                 ...                ...
# 265  {'max_depth': 5, 'max_features': None, 'n_esti...           0.810469
# 266  {'max_depth': 5, 'max_features': None, 'n_esti...           0.808664
# 267  {'max_depth': 5, 'max_features': None, 'n_esti...           0.812274
# 268  {'max_depth': 5, 'max_features': None, 'n_esti...           0.808664
# 269  {'max_depth': 5, 'max_features': None, 'n_esti...           0.814079
#
#      ...  mean_test_score  std_test_score  rank_test_score  \
# 0    ...         0.788010        0.000834              187
# 1    ...         0.788010        0.000834              187
# 2    ...         0.788010        0.000834              187
# 3    ...         0.788010        0.000834              187
# 4    ...         0.788010        0.000834              187
# ..   ...              ...             ...              ...
# 265  ...         0.810770        0.011383               58
# 266  ...         0.811494        0.013326               35
# 267  ...         0.812215        0.012021               19
# 268  ...         0.811854        0.011932               28
# 269  ...         0.813660        0.012675               12
#
#      split0_train_score  split1_train_score  split2_train_score  \
# 0              0.787810            0.787810            0.788262
# 1              0.787810            0.787810            0.788262
# 2              0.787810            0.787810            0.788262
# 3              0.787810            0.787810            0.788262
# 4              0.787810            0.787810            0.788262
# ..                  ...                 ...                 ...
# 265            0.851919            0.855530            0.846050
# 266            0.855079            0.859142            0.846501
# 267            0.858239            0.856885            0.846501
# 268            0.852370            0.859142            0.847856
# 269            0.853725            0.858691            0.847856
#
#      split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0              0.788262            0.787906          0.788010         0.000208
# 1              0.788262            0.787906          0.788010         0.000208
# 2              0.788262            0.787906          0.788010         0.000208
# 3              0.788262            0.787906          0.788010         0.000208
# 4              0.788262            0.787906          0.788010         0.000208
# ..                  ...                 ...               ...              ...
# 265            0.859594            0.851986          0.853016         0.004481
# 266            0.855530            0.847473          0.852745         0.004918
# 267            0.855530            0.846119          0.852655         0.005252
# 268            0.856885            0.849278          0.853106         0.004324
# 269            0.858691            0.851083          0.854009         0.004251
#
# [270 rows x 24 columns]

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

plot_confusion_matrix(rf, X_test, y_test)  
plt.show()

# %%
from sklearn.metrics import plot_roc_curve
rf_disp = plot_roc_curve(rf, X_test, y_test)
plt.show()

# %%
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import ConfusionMatrixDisplay

# cm = confusion_matrix(y_test, predictions, labels=rf.classes_)
# disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#                                display_labels=rf.classes_)
# print(disp)
# disp.plot() 
# print(cm)
# print(rf.classes_)
# print(disp)
# plt.show()

# %%
# from sklearn import metrics
# metrics.plot_det_curve(rf, X_test, y_test)  
# plt.show()
