# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing both data
red = pd.read_csv('Resources/Data/winequality-red.csv', delimiter=';')
white = pd. read_csv('Resources/Data/winequality-white.csv', delimiter=';')

# %%
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red.drop_duplicates()
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white.drop_duplicates()
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#combining two datas into one
#create color segment for each data set
color_red = np.repeat('red', red.shape[0])
color_white = np.repeat('white', white.shape[0])

#append colums to each data set
red['color'] = color_red
white['color'] = color_white

#combine two dataframe
all_wine = red.append(white)

all_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
var = red.columns.tolist()
print(var)
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'color']

# %% [markdown]
# # Red Wine

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## Quality vs all factors
# #### higher quality wine has higher citric acid, sulphates, alcohol, lower volatile acidity, (lower density, pH)

# %%
sns.set_style('ticks')
sns.set_context('notebook')
var = red.columns.tolist()
plt.figure(figsize = (20, 16))
for i in range(12):
    plt.subplot(3,4, i+1)
    sns.boxplot(x = red['quality'], y = var[i], data = red)
    plt.ylabel(var[i], fontsize = 12)
    plt.savefig(f"Images/red_boxplot")
plt.show()

# %%
plt.figure(figsize = (20,16))
sns.heatmap(red[var].corr(), linewidths=1.0, annot=True, fmt='0.2f', cmap="PuBuGn")
plt.savefig(f"Images/red_heatmap")
plt.show()

# %%
sns.set_style('ticks')
sns.set_context('notebook')
var = red.columns.tolist()
plt.figure(figsize = (20, 16))
for i in range(12):
    plt.subplot(3,4, i+1)
    sns.violinplot(x = red['quality'], y = var[i], data = red)
    plt.ylabel(var[i], fontsize = 12)
    plt.savefig(f"Images/red_violinplot")
plt.show()

# %% [markdown]
# # White Wine

# %%
white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ## Quality vs all factors
# #### higher quality white wine has higher alcohol, lower density

# %%
sns.set_style('ticks')
sns.set_context('notebook')
var = white.columns.tolist()
plt.figure(figsize = (20, 16))
for i in range(12):
    plt.subplot(3,4, i+1)
    sns.boxplot(x = white['quality'], y = var[i], data = white)
    plt.ylabel(var[i], fontsize = 12)
    plt.savefig(f"Images/white_boxplot")
plt.show()

# %%
plt.figure(figsize = (20,16))
sns.heatmap(white[var].corr(), linewidths=1.0, annot=True, fmt='0.2f', cmap="PuBuGn")
plt.savefig(f"Images/white_heatmap")
plt.show()

# %%
sns.set_style('ticks')
sns.set_context('notebook')
var = white.columns.tolist()
plt.figure(figsize = (20, 16))
for i in range(12):
    plt.subplot(3,4, i+1)
    sns.violinplot(x = white['quality'], y = var[i], data = white)
    plt.ylabel(var[i], fontsize = 12)
    plt.savefig(f"Images/white_violinplot")
plt.show()
